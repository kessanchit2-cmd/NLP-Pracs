# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/NLP-Pracs/blob/main/Lemitization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
# Download required datasets
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Create lemmatizer object
lemmatizer = WordNetLemmatizer()

# %%
# Input sentence
text = "The boys are playing football and studying hard"

# %%
nltk.download('punkt_tab')
# Tokenize sentence into words
tokens = word_tokenize(text)
print("Original Words:\n")
print(tokens)

print("\nLemmatized Words:\n")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# Original Words:
#
# ['The', 'boys', 'are', 'playing', 'football', 'and', 'studying', 'hard']
#
# Lemmatized Words:
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Perform lemmatization
for word in tokens:
    lemma = lemmatizer.lemmatize(word)
    print(f"{word} --> {lemma}")
# Out:
# The --> The
# boys --> boy
# are --> are
# playing --> playing
# football --> football
# and --> and
# studying --> studying
# hard --> hard
