# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/NLP-Pracs/blob/main/Ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

# %%
# Download tokenizer
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Input sentence
text = "I love machine learning and artificial intelligence"

# %%
# Tokenize words
tokens = word_tokenize(text)

# %%
# Generate Unigrams
unigrams = list(ngrams(tokens, 1))

# %%
# Generate Trigrams
trigrams = list(ngrams(tokens, 3))

# %%
# Generate Bigrams
bigrams = list(ngrams(tokens, 2))

# %%
# Display results
print("Unigrams:\n")
for gram in unigrams:
    print(gram)

print("\nBigrams:\n")
for gram in bigrams:
    print(gram)

print("\nTrigrams:\n")
for gram in trigrams:
    print(gram)
# Out:
# Unigrams:
#
# ('I',)
# ('love',)
# ('machine',)
# ('learning',)
# ('and',)
# ('artificial',)
# ('intelligence',)
#
# Bigrams:
#
# ('I', 'love')
# ('love', 'machine')
# ('machine', 'learning')
# ('learning', 'and')
# ('and', 'artificial')
# ('artificial', 'intelligence')
#
# Trigrams:
#
# ('I', 'love', 'machine')
# ('love', 'machine', 'learning')
# ('machine', 'learning', 'and')
# ('learning', 'and', 'artificial')
# ('and', 'artificial', 'intelligence')
