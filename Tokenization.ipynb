# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/NLP-Pracs/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#Download tokenizer
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Input text
text = """
Artificial Intelligence is transforming the world.
Machine Learning is a part of AI.
Python is widely used in NLP.
"""

# %%
# Sentence Tokenization
sentence_tokens = sent_tokenize(text)

# %%
# Word Tokenization
word_tokens = word_tokenize(text)

# %%
# Display sentence tokens
print("Sentence Tokens:\n")

for sentence in sentence_tokens:
    print(sentence)
# Out:
# Sentence Tokens:
#
#
# Artificial Intelligence is transforming the world.
# Machine Learning is a part of AI.
# Python is widely used in NLP.

# %%
# Display word tokens
print("\nWord Tokens:\n")

print(word_tokens)
# Out:
# Word Tokens:
#
# ['Artificial', 'Intelligence', 'is', 'transforming', 'the', 'world', '.', 'Machine', 'Learning', 'is', 'a', 'part', 'of', 'AI', '.', 'Python', 'is', 'widely', 'used', 'in', 'NLP', '.']
