# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/NLP-Pracs/blob/main/BagOFWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Input sentences
sentences = [
    "I love machine learning",
    "Machine learning is powerful"
]

# %%
# Create CountVectorizer object
vectorizer = CountVectorizer()

# %%
# Fit and transform data
X = vectorizer.fit_transform(sentences)

# %%
# Get feature names (vocabulary)
features = vectorizer.get_feature_names_out()

# %%
# Convert sparse matrix to array
bow_array = X.toarray()

# %%
# Display vocabulary
print("Vocabulary:\n")
print(features)
# Out:
# Vocabulary:
#
# ['is' 'learning' 'love' 'machine' 'powerful']

# %%
# Display Bag of Words matrix
print("\nBag of Words Matrix:\n")
print(bow_array)
# Out:
# Bag of Words Matrix:
#
# [[0 1 1 1 0]
#  [1 1 0 1 1]]
