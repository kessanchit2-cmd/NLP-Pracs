# %% [markdown]
# <a href="https://colab.research.google.com/github/kessanchit2-cmd/NLP-Pracs/blob/main/Stopword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download required datasets
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Input sentence
text = "This is a simple program to remove stopwords from a sentence"

# %%
# Tokenize sentence
words = word_tokenize(text)

# %%
# Load English stopwords
stop_words = set(stopwords.words('english'))

# %%
# Remove stopwords
filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)

# %%
# Display results
print("Original Words:\n")
print(words)

print("\nFiltered Words after Stopwords Removal:\n")
print(filtered_words)
# Out:
# Original Words:
#
# ['This', 'is', 'a', 'simple', 'program', 'to', 'remove', 'stopwords', 'from', 'a', 'sentence']
#
# Filtered Words after Stopwords Removal:
#
# ['simple', 'program', 'remove', 'stopwords', 'sentence']
